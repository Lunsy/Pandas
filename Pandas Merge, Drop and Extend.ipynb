# %%
import pandas as pd
import numpy as np

# %%
forum_users = {
    'User ID': np.array([1, 2, 3, 4, 5]),
    'Username': ['kayrat_i', 'jane_smith', 'bonkavonka', 'areston','mark_wilson'],
    'Age': [18, 35, 25, 38, None],
    'Joined Date': pd.to_datetime(['2032-01-01', '2032-02-15', '2032-04-25', '2032-06-21', '2032-09-15',]),
    'Total Posts': [150, 230, 80, 420, 310],
    'Reputation': [500, 720, 200, 940, 500]

}

df = pd.DataFrame(forum_users)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation
# 0        1     kayrat_i  18.0  2032-01-01          150         500
# 1        2   jane_smith  35.0  2032-02-15          230         720
# 2        3   bonkavonka  25.0  2032-04-25           80         200
# 3        4      areston  38.0  2032-06-21          420         940
# 4        5  mark_wilson   NaN  2032-09-15          310         500

# %%
df['Language'] = 'English'
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language
# 0        1     kayrat_i  18.0  2032-01-01          150         500  English
# 1        2   jane_smith  35.0  2032-02-15          230         720  English
# 2        3   bonkavonka  25.0  2032-04-25           80         200  English
# 3        4      areston  38.0  2032-06-21          420         940  English
# 4        5  mark_wilson   NaN  2032-09-15          310         500  English

# %%
df['Active '] = np.array([True, False, False, True, True])
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     kayrat_i  18.0  2032-01-01          150         500  English
# 1        2   jane_smith  35.0  2032-02-15          230         720  English
# 2        3   bonkavonka  25.0  2032-04-25           80         200  English
# 3        4      areston  38.0  2032-06-21          420         940  English
# 4        5  mark_wilson   NaN  2032-09-15          310         500  English
#
#    Active
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True

# %%
total_comments = {
    'Total Comments': [70, 30, 45, 55, 80]
}
df2 = pd.DataFrame(total_comments)
df2
# Out:
#    Total Comments
# 0              70
# 1              30
# 2              45
# 3              55
# 4              80

# %%
 # By default concat works on the Axis 0!
pd.concat([df, df2])
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0      1.0     kayrat_i  18.0  2032-01-01        150.0       500.0  English
# 1      2.0   jane_smith  35.0  2032-02-15        230.0       720.0  English
# 2      3.0   bonkavonka  25.0  2032-04-25         80.0       200.0  English
# 3      4.0      areston  38.0  2032-06-21        420.0       940.0  English
# 4      5.0  mark_wilson   NaN  2032-09-15        310.0       500.0  English
# 0      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 1      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 2      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 3      NaN          NaN   NaN         NaT          NaN         NaN      NaN
# 4      NaN          NaN   NaN         NaT          NaN         NaN      NaN
#
#   Active   Total Comments
# 0    True             NaN
# 1   False             NaN
# 2   False             NaN
# 3    True             NaN
# 4    True             NaN
# 0     NaN            70.0
# 1     NaN            30.0
# 2     NaN            45.0
# 3     NaN            55.0
# 4     NaN            80.0

# %%
 df = pd.concat([df, df2], axis=1)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     kayrat_i  18.0  2032-01-01          150         500  English
# 1        2   jane_smith  35.0  2032-02-15          230         720  English
# 2        3   bonkavonka  25.0  2032-04-25           80         200  English
# 3        4      areston  38.0  2032-06-21          420         940  English
# 4        5  mark_wilson   NaN  2032-09-15          310         500  English
#
#    Active   Total Comments
# 0     True              70
# 1    False              30
# 2    False              45
# 3     True              55
# 4     True              80

# %%
# Original df doesn't change
df.drop(['Language'], axis=1)
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active   \
# 0        1     kayrat_i  18.0  2032-01-01          150         500     True
# 1        2   jane_smith  35.0  2032-02-15          230         720    False
# 2        3   bonkavonka  25.0  2032-04-25           80         200    False
# 3        4      areston  38.0  2032-06-21          420         940     True
# 4        5  mark_wilson   NaN  2032-09-15          310         500     True
#
#    Total Comments
# 0              70
# 1              30
# 2              45
# 3              55
# 4              80

# %%
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation Language  \
# 0        1     kayrat_i  18.0  2032-01-01          150         500  English
# 1        2   jane_smith  35.0  2032-02-15          230         720  English
# 2        3   bonkavonka  25.0  2032-04-25           80         200  English
# 3        4      areston  38.0  2032-06-21          420         940  English
# 4        5  mark_wilson   NaN  2032-09-15          310         500  English
#
#    Active   Total Comments
# 0     True              70
# 1    False              30
# 2    False              45
# 3     True              55
# 4     True              80

# %%
# Original df is changed inplace
df.drop(['Language', 'Total Comments'], axis=1, inplace=True)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     kayrat_i  18.0  2032-01-01          150         500     True
# 1        2   jane_smith  35.0  2032-02-15          230         720    False
# 2        3   bonkavonka  25.0  2032-04-25           80         200    False
# 3        4      areston  38.0  2032-06-21          420         940     True
# 4        5  mark_wilson   NaN  2032-09-15          310         500     True

# %%
df.drop([2, 3], inplace=True)
df
# Out:
#    User ID     Username   Age Joined Date  Total Posts  Reputation  Active
# 0        1     kayrat_i  18.0  2032-01-01          150         500     True
# 1        2   jane_smith  35.0  2032-02-15          230         720    False
# 4        5  mark_wilson   NaN  2032-09-15          310         500     True
